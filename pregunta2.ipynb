# %%
for letra in "Python": 
    print(letra)
# Out:
# P
# y
# t
# h
# o
# n

# %%
#Ejemplo while:
contador = 1 
while contador <= 5:
    print(contador) 
    contador += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for fruta in ["manzana", "banana", "sandía"]:
    if fruta == "sandía":
        break       # PARA
    print(fruta)    # manzana banana
# Out:
# manzana
# banana
